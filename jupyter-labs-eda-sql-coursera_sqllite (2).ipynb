# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.3.9
# Out:
# Collecting sqlalchemy==1.3.9
#   Downloading SQLAlchemy-1.3.9.tar.gz (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 80.3 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.9-cp37-cp37m-linux_x86_64.whl size=1159121 sha256=ddef7044a07ba2bd4c3845ea3ecae38ca97db9f60157853ed6de6756104477b7
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/03/71/13/010faf12246f72dc76b4150e6e599d13a85b4435e06fb9e51f
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.24
#     Uninstalling SQLAlchemy-1.3.24:
#       Successfully uninstalled SQLAlchemy-1.3.24
# Successfully installed sqlalchemy-1.3.9

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
conda update pandas
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     absl-py-0.15.0             |     pyhd3eb1b0_0         103 KB
#     astor-0.8.1                |   py37h06a4308_0          47 KB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     blas-1.0                   |              mkl           6 KB
#     brotli-1.0.9               |       h5eee18b_7          18 KB
#     brotli-bin-1.0.9           |       h5eee18b_7          19 KB
#     brotli-python-1.0.9        |   py37h6a678d5_7         329 KB
#     brotlipy-0.7.0             |py37h27cfd23_1003         320 KB
#     bzip2-1.0.8                |       h5eee18b_5         262 KB
#     c-ares-1.19.1              |       h5eee18b_0         118 KB
#     ca-certificates-2024.3.11  |       h06a4308_0         127 KB
#     cairo-1.16.0               |       hb05425b_5         1.2 MB
#     certifi-2020.6.20          |     pyhd3eb1b0_3         155 KB
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          35 KB
#     click-8.0.3                |     pyhd3eb1b0_0          79 KB
#     cloudpickle-2.0.0          |     pyhd3eb1b0_0          32 KB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     dataclasses-0.8            |     pyh6d0b6a4_7           8 KB
#     dbus-1.13.18               |       hb2f20db_0         504 KB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     entrypoints-0.4            |   py37h06a4308_0          16 KB
#     expat-2.5.0                |       h6a678d5_0         172 KB
#     flask-2.0.3                |     pyhd3eb1b0_0          76 KB
#     flask-compress-1.13        |   py37h06a4308_0          19 KB
#     fonttools-4.25.0           |     pyhd3eb1b0_0         632 KB
#     freetype-2.12.1            |       h4a9f257_0         626 KB
#     fribidi-1.0.10             |       h7b6447c_0         103 KB
#     fsspec-2022.2.0            |     pyhd3eb1b0_0          98 KB
#     gast-0.5.3                 |     pyhd3eb1b0_0          21 KB
#     gettext-0.21.0             |       hf68c758_0         2.6 MB
#     giflib-5.2.1               |       h5eee18b_3          80 KB
#     glib-2.78.4                |       h6a678d5_0         508 KB
#     glib-tools-2.78.4          |       h6a678d5_0         115 KB
#     gmp-6.2.1                  |       h295c915_3         544 KB
#     google-pasta-0.2.0         |     pyhd3eb1b0_0          46 KB
#     graphite2-1.3.14           |       h295c915_1          97 KB
#     grpcio-1.42.0              |   py37hce63b2e_0         2.1 MB
#     idna-3.4                   |   py37h06a4308_0          91 KB
#     imageio-2.9.0              |     pyhd3eb1b0_0         3.0 MB
#     importlib-metadata-4.11.3  |   py37h06a4308_0          40 KB
#     itsdangerous-2.0.1         |     pyhd3eb1b0_0          18 KB
#     jasper-1.900.1             |       hd497a04_4         198 KB
#     jedi-0.18.1                |   py37h06a4308_1         980 KB
#     jinja2-3.0.3               |     pyhd3eb1b0_0         106 KB
#     jpeg-9e                    |       h5eee18b_1         262 KB
#     jupyter_client-7.4.9       |   py37h06a4308_0         204 KB
#     keras-applications-1.0.8   |             py_1          29 KB
#     keras-preprocessing-1.1.2  |     pyhd3eb1b0_0          35 KB
#     kiwisolver-1.4.4           |   py37h6a678d5_0          74 KB
#     krb5-1.19.4                |       h568e23c_0         1.3 MB
#     lame-3.100                 |       h7b6447c_0         323 KB
#     lcms2-2.12                 |       h3be6417_0         312 KB
#     libarchive-3.4.2           |       h62408e4_0         796 KB
#     libbrotlicommon-1.0.9      |       h5eee18b_7          70 KB
#     libbrotlidec-1.0.9         |       h5eee18b_7          31 KB
#     libbrotlienc-1.0.9         |       h5eee18b_7         264 KB
#     libedit-3.1.20230828       |       h5eee18b_0         179 KB
#     libev-4.33                 |       h7f8727e_1         111 KB
#     libffi-3.4.4               |       h6a678d5_0         142 KB
#     libgfortran-ng-11.2.0      |       h00389a5_1          20 KB
#     libgfortran5-11.2.0        |       h1234567_1         2.0 MB
#     libglib-2.78.4             |       hdc74915_0         1.5 MB
#     libiconv-1.16              |       h7f8727e_2         736 KB
#     libllvm11-11.1.0           |       h9e868ea_6        24.1 MB
#     libnsl-2.0.0               |       h5eee18b_0          31 KB
#     libogg-1.3.5               |       h27cfd23_1         199 KB
#     libopus-1.3.1              |       h7b6447c_0         491 KB
#     libpng-1.6.39              |       h5eee18b_0         304 KB
#     libprotobuf-3.20.3         |       he621ea3_0         2.4 MB
#     libsodium-1.0.18           |       h7b6447c_0         244 KB
#     libssh2-1.10.0             |       h37d81fd_2         292 KB
#     libtool-2.4.6              |    h6a678d5_1009         421 KB
#     libvorbis-1.3.7            |       h7b6447c_0         398 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     llvm-openmp-14.0.6         |       h9e868ea_0         4.4 MB
#     locket-1.0.0               |   py37h06a4308_0          11 KB
#     lz4-c-1.9.4                |       h6a678d5_0         154 KB
#     markdown-3.4.1             |   py37h06a4308_0         132 KB
#     matplotlib-inline-0.1.6    |   py37h06a4308_0          16 KB
#     munkres-1.1.4              |             py_0          13 KB
#     ncurses-6.4                |       h6a678d5_0         914 KB
#     nest-asyncio-1.5.6         |   py37h06a4308_0          14 KB
#     ninja-1.10.2               |       h06a4308_5           8 KB
#     ninja-base-1.10.2          |       hd09550d_5         109 KB
#     nspr-4.35                  |       h6a678d5_0         244 KB
#     nss-3.89.1                 |       h6a678d5_0         2.1 MB
#     olefile-0.46               |           py37_0          50 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     packaging-21.3             |     pyhd3eb1b0_0          36 KB
#     parso-0.8.3                |     pyhd3eb1b0_0          70 KB
#     partd-1.2.0                |     pyhd3eb1b0_1          18 KB
#     pcre2-10.42                |       hebb0a14_0         1.5 MB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB
#     pixman-0.40.0              |       h7f8727e_1         373 KB
#     prompt-toolkit-3.0.20      |     pyhd3eb1b0_0         259 KB
#     protobuf-3.20.3            |   py37h6a678d5_0         324 KB
#     psutil-5.9.0               |   py37h5eee18b_0         328 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_2          17 KB
#     pycparser-2.21             |     pyhd3eb1b0_0          94 KB
#     pygments-2.11.2            |     pyhd3eb1b0_0         759 KB
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          50 KB
#     pyparsing-3.0.9            |   py37h06a4308_0         150 KB
#     pyshp-2.1.3                |     pyhd3eb1b0_0          37 KB
#     pysocks-1.7.1              |           py37_1          27 KB
#     python-dateutil-2.8.2      |     pyhd3eb1b0_0         233 KB
#     pytz-2021.3                |     pyhd3eb1b0_0         171 KB
#     readline-8.2               |       h5eee18b_0         357 KB
#     requests-2.28.1            |   py37h06a4308_0          92 KB
#     retrying-1.3.3             |           py37_2          16 KB
#     six-1.16.0                 |     pyhd3eb1b0_1          18 KB
#     soupsieve-2.3.1            |     pyhd3eb1b0_0          34 KB
#     sqlite-3.41.2              |       h5eee18b_0         1.2 MB
#     termcolor-2.1.0            |   py37h06a4308_0          11 KB
#     tk-8.6.12                  |       h1ccaba5_0         3.0 MB
#     toolz-0.12.0               |   py37h06a4308_0         104 KB
#     traitlets-5.7.1            |   py37h06a4308_0         199 KB
#     typing_extensions-4.1.1    |     pyh06a4308_0          28 KB
#     urllib3-1.26.8             |     pyhd3eb1b0_0         106 KB
#     wcwidth-0.2.5              |     pyhd3eb1b0_0          26 KB
#     werkzeug-2.0.3             |     pyhd3eb1b0_0         221 KB
#     wheel-0.37.1               |     pyhd3eb1b0_0          33 KB
#     wrapt-1.14.1               |   py37h5eee18b_0          50 KB
#     xorg-xproto-7.0.31         |    h27cfd23_1007          73 KB
#     yaml-0.2.5                 |       h7b6447c_0          75 KB
#     zeromq-4.3.5               |       h6a678d5_0         366 KB
#     zipp-3.7.0                 |     pyhd3eb1b0_0          12 KB
#     zstd-1.4.9                 |       haebb681_0         480 KB
#     ------------------------------------------------------------
#                                            Total:        75.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   dataclasses        pkgs/main/noarch::dataclasses-0.8-pyh6d0b6a4_7
#   glib               pkgs/main/linux-64::glib-2.78.4-h6a678d5_0
#   glib-tools         pkgs/main/linux-64::glib-tools-2.78.4-h6a678d5_0
#   ninja-base         pkgs/main/linux-64::ninja-base-1.10.2-hd09550d_5
#
# The following packages will be REMOVED:
#
#   backports-1.0-pyhd8ed1ab_3
#   backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0
#   grpc-cpp-1.48.1-h05bd8bd_1
#   keyutils-1.6.1-h166bdaf_0
#   libabseil-20220623.0-cxx17_h05df665_6
#   libexpat-2.5.0-hcb278e6_1
#   libsqlite-3.42.0-h2797004_0
#   lzo-2.10-h516909a_1000
#   pthread-stubs-0.4-h36c2ea0_1001
#   re2-2022.06.01-h27087fc_1
#   typing-extensions-4.5.0-hd8ed1ab_0
#   unicodedata2-14.0.0-py37h540881e_1
#   xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp-1.1.3-h7f98852_0
#
# The following packages will be UPDATED:
#
#   blas                                          conda-forge --> pkgs/main
#   bzip2                 conda-forge::bzip2-1.0.8-h7f98852_4 --> pkgs/main::bzip2-1.0.8-h5eee18b_5
#   c-ares              conda-forge::c-ares-1.19.0-hd590300_0 --> pkgs/main::c-ares-1.19.1-h5eee18b_0
#   ca-certificates    conda-forge::ca-certificates-2023.5.7~ --> pkgs/main::ca-certificates-2024.3.11-h06a4308_0
#   dbus                  conda-forge::dbus-1.13.6-h5008d03_3 --> pkgs/main::dbus-1.13.18-hb2f20db_0
#   gmp                     conda-forge::gmp-6.2.1-h58526e2_0 --> pkgs/main::gmp-6.2.1-h295c915_3
#   graphite2          conda-forge::graphite2-1.3.13-h58526e~ --> pkgs/main::graphite2-1.3.14-h295c915_1
#   krb5                  conda-forge::krb5-1.19.3-h3790be6_0 --> pkgs/main::krb5-1.19.4-h568e23c_0
#   lcms2                  conda-forge::lcms2-2.11-hcbb858e_1 --> pkgs/main::lcms2-2.12-h3be6417_0
#   libedit            conda-forge::libedit-3.1.20191231-he2~ --> pkgs/main::libedit-3.1.20230828-h5eee18b_0
#   libffi               conda-forge::libffi-3.4.2-h7f98852_5 --> pkgs/main::libffi-3.4.4-h6a678d5_0
#   libglib            conda-forge::libglib-2.76.2-hebfc3b9_0 --> pkgs/main::libglib-2.78.4-hdc74915_0
#   libllvm11          conda-forge::libllvm11-11.1.0-he0ac6c~ --> pkgs/main::libllvm11-11.1.0-h9e868ea_6
#   libogg               conda-forge::libogg-1.3.4-h7f98852_1 --> pkgs/main::libogg-1.3.5-h27cfd23_1
#   lz4-c                 conda-forge::lz4-c-1.9.3-h9c3ff4c_1 --> pkgs/main::lz4-c-1.9.4-h6a678d5_0
#   ncurses               conda-forge::ncurses-6.3-h27087fc_1 --> pkgs/main::ncurses-6.4-h6a678d5_0
#   nss                      conda-forge::nss-3.89-he45b914_0 --> pkgs/main::nss-3.89.1-h6a678d5_0
#   openssl            conda-forge::openssl-1.1.1t-h0b41bf4_0 --> pkgs/main::openssl-1.1.1w-h7f8727e_0
#   pcre2                 conda-forge::pcre2-10.40-hc3806b6_0 --> pkgs/main::pcre2-10.42-hebb0a14_0
#   pexpect            conda-forge::pexpect-4.8.0-pyh1a96a4e~ --> pkgs/main::pexpect-4.8.0-pyhd3eb1b0_3
#   pixman              conda-forge::pixman-0.40.0-h36c2ea0_0 --> pkgs/main::pixman-0.40.0-h7f8727e_1
#   ptyprocess         conda-forge::ptyprocess-0.7.0-pyhd3de~ --> pkgs/main::ptyprocess-0.7.0-pyhd3eb1b0_2
#   six                  conda-forge::six-1.16.0-pyh6c4a22f_0 --> pkgs/main::six-1.16.0-pyhd3eb1b0_1
#   zeromq               conda-forge::zeromq-4.3.4-h9c3ff4c_1 --> pkgs/main::zeromq-4.3.5-h6a678d5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   absl-py            conda-forge::absl-py-1.4.0-pyhd8ed1ab~ --> pkgs/main::absl-py-0.15.0-pyhd3eb1b0_0
#   astor              conda-forge/noarch::astor-0.8.1-pyh9f~ --> pkgs/main/linux-64::astor-0.8.1-py37h06a4308_0
#   backcall           conda-forge::backcall-0.2.0-pyh9f0ad1~ --> pkgs/main::backcall-0.2.0-pyhd3eb1b0_0
#   brotli               conda-forge::brotli-1.0.9-h166bdaf_8 --> pkgs/main::brotli-1.0.9-h5eee18b_7
#   brotli-bin         conda-forge::brotli-bin-1.0.9-h166bda~ --> pkgs/main::brotli-bin-1.0.9-h5eee18b_7
#   brotli-python      conda-forge::brotli-python-1.0.9-py37~ --> pkgs/main::brotli-python-1.0.9-py37h6a678d5_7
#   brotlipy           conda-forge::brotlipy-0.7.0-py37h5408~ --> pkgs/main::brotlipy-0.7.0-py37h27cfd23_1003
#   cairo              conda-forge::cairo-1.16.0-h6cf1ce9_10~ --> pkgs/main::cairo-1.16.0-hb05425b_5
#   certifi            conda-forge::certifi-2023.5.7-pyhd8ed~ --> pkgs/main::certifi-2020.6.20-pyhd3eb1b0_3
#   charset-normalizer conda-forge::charset-normalizer-3.1.0~ --> pkgs/main::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   click              conda-forge/linux-64::click-8.1.3-py3~ --> pkgs/main/noarch::click-8.0.3-pyhd3eb1b0_0
#   cloudpickle        conda-forge::cloudpickle-2.2.1-pyhd8e~ --> pkgs/main::cloudpickle-2.0.0-pyhd3eb1b0_0
#   cycler             conda-forge::cycler-0.11.0-pyhd8ed1ab~ --> pkgs/main::cycler-0.11.0-pyhd3eb1b0_0
#   decorator          conda-forge::decorator-5.1.1-pyhd8ed1~ --> pkgs/main::decorator-5.1.1-pyhd3eb1b0_0
#   entrypoints        conda-forge/noarch::entrypoints-0.4-p~ --> pkgs/main/linux-64::entrypoints-0.4-py37h06a4308_0
#   expat                 conda-forge::expat-2.5.0-hcb278e6_1 --> pkgs/main::expat-2.5.0-h6a678d5_0
#   flask               conda-forge::flask-2.2.3-pyhd8ed1ab_0 --> pkgs/main::flask-2.0.3-pyhd3eb1b0_0
#   flask-compress     conda-forge/noarch::flask-compress-1.~ --> pkgs/main/linux-64::flask-compress-1.13-py37h06a4308_0
#   fonttools          conda-forge/linux-64::fonttools-4.38.~ --> pkgs/main/noarch::fonttools-4.25.0-pyhd3eb1b0_0
#   freetype           conda-forge::freetype-2.12.1-hca18f0e~ --> pkgs/main::freetype-2.12.1-h4a9f257_0
#   fribidi            conda-forge::fribidi-1.0.10-h36c2ea0_0 --> pkgs/main::fribidi-1.0.10-h7b6447c_0
#   fsspec             conda-forge::fsspec-2023.1.0-pyhd8ed1~ --> pkgs/main::fsspec-2022.2.0-pyhd3eb1b0_0
#   gast                 conda-forge::gast-0.5.3-pyhd8ed1ab_0 --> pkgs/main::gast-0.5.3-pyhd3eb1b0_0
#   gettext            conda-forge::gettext-0.21.1-h27087fc_0 --> pkgs/main::gettext-0.21.0-hf68c758_0
#   giflib               conda-forge::giflib-5.2.1-h0b41bf4_3 --> pkgs/main::giflib-5.2.1-h5eee18b_3
#   google-pasta       conda-forge::google-pasta-0.2.0-pyh8c~ --> pkgs/main::google-pasta-0.2.0-pyhd3eb1b0_0
#   grpcio             conda-forge::grpcio-1.48.1-py37h3fae8~ --> pkgs/main::grpcio-1.42.0-py37hce63b2e_0
#   idna               conda-forge/noarch::idna-3.4-pyhd8ed1~ --> pkgs/main/linux-64::idna-3.4-py37h06a4308_0
#   imageio            conda-forge::imageio-2.13.1-pyhd8ed1a~ --> pkgs/main::imageio-2.9.0-pyhd3eb1b0_0
#   importlib-metadata conda-forge::importlib-metadata-4.11.~ --> pkgs/main::importlib-metadata-4.11.3-py37h06a4308_0
#   itsdangerous       conda-forge::itsdangerous-2.1.2-pyhd8~ --> pkgs/main::itsdangerous-2.0.1-pyhd3eb1b0_0
#   jasper             conda-forge::jasper-1.900.1-h07fcdf6_~ --> pkgs/main::jasper-1.900.1-hd497a04_4
#   jedi               conda-forge/noarch::jedi-0.18.2-pyhd8~ --> pkgs/main/linux-64::jedi-0.18.1-py37h06a4308_1
#   jinja2             conda-forge::jinja2-3.1.2-pyhd8ed1ab_1 --> pkgs/main::jinja2-3.0.3-pyhd3eb1b0_0
#   jpeg                      conda-forge::jpeg-9e-h0b41bf4_3 --> pkgs/main::jpeg-9e-h5eee18b_1
#   jupyter_client     conda-forge/noarch::jupyter_client-7.~ --> pkgs/main/linux-64::jupyter_client-7.4.9-py37h06a4308_0
#   keras-applications                            conda-forge --> pkgs/main
#   keras-preprocessi~ conda-forge::keras-preprocessing-1.1.~ --> pkgs/main::keras-preprocessing-1.1.2-pyhd3eb1b0_0
#   kiwisolver         conda-forge::kiwisolver-1.4.4-py37h7c~ --> pkgs/main::kiwisolver-1.4.4-py37h6a678d5_0
#   lame                conda-forge::lame-3.100-h166bdaf_1003 --> pkgs/main::lame-3.100-h7b6447c_0
#   libarchive         conda-forge::libarchive-3.5.1-h3f442f~ --> pkgs/main::libarchive-3.4.2-h62408e4_0
#   libbrotlicommon    conda-forge::libbrotlicommon-1.0.9-h1~ --> pkgs/main::libbrotlicommon-1.0.9-h5eee18b_7
#   libbrotlidec       conda-forge::libbrotlidec-1.0.9-h166b~ --> pkgs/main::libbrotlidec-1.0.9-h5eee18b_7
#   libbrotlienc       conda-forge::libbrotlienc-1.0.9-h166b~ --> pkgs/main::libbrotlienc-1.0.9-h5eee18b_7
#   libev                  conda-forge::libev-4.33-h516909a_1 --> pkgs/main::libev-4.33-h7f8727e_1
#   libgfortran-ng     conda-forge::libgfortran-ng-12.2.0-h6~ --> pkgs/main::libgfortran-ng-11.2.0-h00389a5_1
#   libgfortran5       conda-forge::libgfortran5-12.2.0-h337~ --> pkgs/main::libgfortran5-11.2.0-h1234567_1
#   libiconv            conda-forge::libiconv-1.17-h166bdaf_0 --> pkgs/main::libiconv-1.16-h7f8727e_2
#   libnsl               conda-forge::libnsl-2.0.0-h7f98852_0 --> pkgs/main::libnsl-2.0.0-h5eee18b_0
#   libopus             conda-forge::libopus-1.3.1-h7f98852_1 --> pkgs/main::libopus-1.3.1-h7b6447c_0
#   libpng              conda-forge::libpng-1.6.39-h753d276_0 --> pkgs/main::libpng-1.6.39-h5eee18b_0
#   libprotobuf        conda-forge::libprotobuf-3.21.8-h6239~ --> pkgs/main::libprotobuf-3.20.3-he621ea3_0
#   libsodium          conda-forge::libsodium-1.0.18-h36c2ea~ --> pkgs/main::libsodium-1.0.18-h7b6447c_0
#   libssh2            conda-forge::libssh2-1.10.0-haa6b8db_3 --> pkgs/main::libssh2-1.10.0-h37d81fd_2
#   libtool             conda-forge::libtool-2.4.7-h27087fc_0 --> pkgs/main::libtool-2.4.6-h6a678d5_1009
#   libvorbis          conda-forge::libvorbis-1.3.7-h9c3ff4c~ --> pkgs/main::libvorbis-1.3.7-h7b6447c_0
#   libxcb                conda-forge::libxcb-1.15-h0b41bf4_0 --> pkgs/main::libxcb-1.15-h7f8727e_0
#   llvm-openmp        conda-forge::llvm-openmp-15.0.7-h0cdc~ --> pkgs/main::llvm-openmp-14.0.6-h9e868ea_0
#   locket             conda-forge/noarch::locket-1.0.0-pyhd~ --> pkgs/main/linux-64::locket-1.0.0-py37h06a4308_0
#   markdown           conda-forge/noarch::markdown-3.4.3-py~ --> pkgs/main/linux-64::markdown-3.4.1-py37h06a4308_0
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline~ --> pkgs/main/linux-64::matplotlib-inline-0.1.6-py37h06a4308_0
#   munkres            conda-forge::munkres-1.1.4-pyh9f0ad1d~ --> pkgs/main::munkres-1.1.4-py_0
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.5.~ --> pkgs/main/linux-64::nest-asyncio-1.5.6-py37h06a4308_0
#   ninja                conda-forge::ninja-1.11.1-h924138e_0 --> pkgs/main::ninja-1.10.2-h06a4308_5
#   nspr                    conda-forge::nspr-4.35-h27087fc_0 --> pkgs/main::nspr-4.35-h6a678d5_0
#   olefile            conda-forge/noarch::olefile-0.46-pyh9~ --> pkgs/main/linux-64::olefile-0.46-py37_0
#   packaging          conda-forge::packaging-23.1-pyhd8ed1a~ --> pkgs/main::packaging-21.3-pyhd3eb1b0_0
#   parso               conda-forge::parso-0.8.3-pyhd8ed1ab_0 --> pkgs/main::parso-0.8.3-pyhd3eb1b0_0
#   partd               conda-forge::partd-1.4.0-pyhd8ed1ab_0 --> pkgs/main::partd-1.2.0-pyhd3eb1b0_1
#   pickleshare        conda-forge::pickleshare-0.7.5-py_1003 --> pkgs/main::pickleshare-0.7.5-pyhd3eb1b0_1003
#   prompt-toolkit     conda-forge::prompt-toolkit-3.0.38-py~ --> pkgs/main::prompt-toolkit-3.0.20-pyhd3eb1b0_0
#   protobuf           conda-forge::protobuf-4.21.8-py37hd23~ --> pkgs/main::protobuf-3.20.3-py37h6a678d5_0
#   psutil             conda-forge::psutil-5.9.3-py37h540881~ --> pkgs/main::psutil-5.9.0-py37h5eee18b_0
#   pycparser          conda-forge::pycparser-2.21-pyhd8ed1a~ --> pkgs/main::pycparser-2.21-pyhd3eb1b0_0
#   pygments           conda-forge::pygments-2.15.1-pyhd8ed1~ --> pkgs/main::pygments-2.11.2-pyhd3eb1b0_0
#   pyopenssl          conda-forge::pyopenssl-23.1.1-pyhd8ed~ --> pkgs/main::pyopenssl-22.0.0-pyhd3eb1b0_0
#   pyparsing          conda-forge/noarch::pyparsing-3.0.9-p~ --> pkgs/main/linux-64::pyparsing-3.0.9-py37h06a4308_0
#   pyshp               conda-forge::pyshp-2.3.1-pyhd8ed1ab_0 --> pkgs/main::pyshp-2.1.3-pyhd3eb1b0_0
#   pysocks            conda-forge::pysocks-1.7.1-py37h89c18~ --> pkgs/main::pysocks-1.7.1-py37_1
#   python-dateutil    conda-forge::python-dateutil-2.8.2-py~ --> pkgs/main::python-dateutil-2.8.2-pyhd3eb1b0_0
#   pytz                conda-forge::pytz-2023.3-pyhd8ed1ab_0 --> pkgs/main::pytz-2021.3-pyhd3eb1b0_0
#   readline             conda-forge::readline-8.2-h8228510_1 --> pkgs/main::readline-8.2-h5eee18b_0
#   requests           conda-forge/noarch::requests-2.29.0-p~ --> pkgs/main/linux-64::requests-2.28.1-py37h06a4308_0
#   retrying           conda-forge/noarch::retrying-1.3.3-py~ --> pkgs/main/linux-64::retrying-1.3.3-py37_2
#   soupsieve          conda-forge::soupsieve-2.3.2.post1-py~ --> pkgs/main::soupsieve-2.3.1-pyhd3eb1b0_0
#   sqlite              conda-forge::sqlite-3.42.0-h2c6b66d_0 --> pkgs/main::sqlite-3.41.2-h5eee18b_0
#   termcolor          conda-forge/noarch::termcolor-2.3.0-p~ --> pkgs/main/linux-64::termcolor-2.1.0-py37h06a4308_0
#   tk                      conda-forge::tk-8.6.12-h27826a3_0 --> pkgs/main::tk-8.6.12-h1ccaba5_0
#   toolz              conda-forge/noarch::toolz-0.12.0-pyhd~ --> pkgs/main/linux-64::toolz-0.12.0-py37h06a4308_0
#   traitlets          conda-forge/noarch::traitlets-5.9.0-p~ --> pkgs/main/linux-64::traitlets-5.7.1-py37h06a4308_0
#   typing_extensions  conda-forge::typing_extensions-4.5.0-~ --> pkgs/main::typing_extensions-4.1.1-pyh06a4308_0
#   urllib3            conda-forge::urllib3-1.26.15-pyhd8ed1~ --> pkgs/main::urllib3-1.26.8-pyhd3eb1b0_0
#   wcwidth            conda-forge::wcwidth-0.2.6-pyhd8ed1ab~ --> pkgs/main::wcwidth-0.2.5-pyhd3eb1b0_0
#   werkzeug           conda-forge::werkzeug-2.2.3-pyhd8ed1a~ --> pkgs/main::werkzeug-2.0.3-pyhd3eb1b0_0
#   wheel              conda-forge::wheel-0.40.0-pyhd8ed1ab_0 --> pkgs/main::wheel-0.37.1-pyhd3eb1b0_0
#   wrapt              conda-forge::wrapt-1.14.1-py37h540881~ --> pkgs/main::wrapt-1.14.1-py37h5eee18b_0
#   xorg-xproto        conda-forge::xorg-xproto-7.0.31-h7f98~ --> pkgs/main::xorg-xproto-7.0.31-h27cfd23_1007
#   yaml                   conda-forge::yaml-0.2.5-h7f98852_2 --> pkgs/main::yaml-0.2.5-h7b6447c_0
#   zipp                conda-forge::zipp-3.15.0-pyhd8ed1ab_0 --> pkgs/main::zipp-3.7.0-pyhd3eb1b0_0
#   zstd                   conda-forge::zstd-1.4.9-ha95c52a_0 --> pkgs/main::zstd-1.4.9-haebb681_0
#
#
#
# Downloading and Extracting Packages
# libglib-2.78.4       | 1.5 MB    |                                       |   0%
# pyshp-2.1.3          | 37 KB     |                                       |   0%
#
# pcre2-10.42          | 1.5 MB    |                                       |   0%
#
#
# fonttools-4.25.0     | 632 KB    |                                       |   0%
#
#
#
# decorator-5.1.1      | 12 KB     |                                       |   0%
#
#
#
#
# ptyprocess-0.7.0     | 17 KB     |                                       |   0%
#
#
#
#
#
# dataclasses-0.8      | 8 KB      |                                       |   0%
#
#
#
#
#
#
# zipp-3.7.0           | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
# cloudpickle-2.0.0    | 32 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 18 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# glib-tools-2.78.4    | 115 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 262 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# backcall-0.2.0       | 13 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-21.3       | 36 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2020.6.20    | 155 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# partd-1.2.0          | 18 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# olefile-0.46         | 50 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 27 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# flask-compress-1.13  | 19 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# pcre2-10.42          | 1.5 MB    | 3                                     |   1%
# libglib-2.78.4       | 1.5 MB    | 3                                     |   1%
#
#
#
# decorator-5.1.1      | 12 KB     | ##################################### | 100%
#
#
#
#
# ptyprocess-0.7.0     | 17 KB     | ##################################6   |  94%
#
#
# fonttools-4.25.0     | 632 KB    | 9                                     |   3%
#
#
#
#
#
# dataclasses-0.8      | 8 KB      | ##################################### | 100%
#
#
#
#
#
#
# zipp-3.7.0           | 12 KB     | ##################################### | 100%
#
# libglib-2.78.4       | 1.5 MB    | #################7                    |  48%
#
#
#
#
#
#
#
# cloudpickle-2.0.0    | 32 KB     | ##################6                   |  50%
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 18 KB     | ################################1     |  87%
#
#
# fonttools-4.25.0     | 632 KB    | #####################5                |  58%
#
#
#
#
#
#
#
#
#
# glib-tools-2.78.4    | 115 KB    | #####1                                |  14%
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     | ###########2                          |  30%
#
# libglib-2.78.4       | 1.5 MB    | ##############################4       |  82%
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 262 KB    | ##2                                   |   6%
# pyshp-2.1.3          | 37 KB     | ##################################### | 100%
# pyshp-2.1.3          | 37 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# backcall-0.2.0       | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-21.3       | 36 KB     | ################2                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2020.6.20    | 155 KB    | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# partd-1.2.0          | 18 KB     | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | 1                                     |   0%
#
#
#
# decorator-5.1.1      | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 27 KB     | #####################6                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# olefile-0.46         | 50 KB     | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# flask-compress-1.13  | 19 KB     | ###############################8      |  86%
#
#
#
#
# ptyprocess-0.7.0     | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 28 KB     | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    | ##############################2       |  82%
#
#
#
#
#
# dataclasses-0.8      | 8 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | #####2                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | ##########3                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | ##############7                       |  40%
#
#
#
#
#
#
# zipp-3.7.0           | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 18 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | ###################8                  |  54%
#
#
#
#
#
#
#
# cloudpickle-2.0.0    | 32 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# cloudpickle-2.0.0    | 32 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | #########################8            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | ###############################6      |  85%
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# glib-tools-2.78.4    | 115 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# glib-tools-2.78.4    | 115 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 262 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 262 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.78.4       | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-21.3       | 36 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-21.3       | 36 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2020.6.20    | 155 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2020.6.20    | 155 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# partd-1.2.0          | 18 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# olefile-0.46         | 50 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# olefile-0.46         | 50 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# flask-compress-1.13  | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 28 KB     | ##################################### | 100%
#
#
# fonttools-4.25.0     | 632 KB    | ##################################### | 100%
#
#
# fonttools-4.25.0     | 632 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# pcre2-10.42          | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1w       | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas==1.1.5

# %%
# %sql sqlite:///my_data1.db
# Out:
# 'Connected: @my_data1.db'

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/generic.py:2882: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   both result in 0.1234 being formatted as 0.12.

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# (sqlite3.OperationalError) table SPACEXTABLE already exists
# [SQL: create table SPACEXTABLE as select * from SPACEXTBL where Date is not null]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %sql select DISTINCT(LAUNCH_SITE) from SPACEXTBL;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',), ('VAFB SLC-4E',), ('KSC LC-39A',), ('CCAFS SLC-40',)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
# %sql SELECT LAUNCH_SITE from SPACEXTBL where (LAUNCH_SITE) LIKE 'CCA%' LIMIT 5;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',)]

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %sql select sum(PAYLOAD_MASS__KG_) as payloadmass from SPACEXTBL;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(619967,)]

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %sql select avg(PAYLOAD_MASS__KG_) as payloadmass from SPACEXTBL;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(6138.287128712871,)]

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
# %sql select min(DATE) from SPACEXTBL;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-06-04',)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %sql select BOOSTER_VERSION from SPACEXTBL where LANDING_OUTCOME='Success (drone ship)' and PAYLOAD_MASS__KG_ BETWEEN 4000 and 6000;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT B1022',), ('F9 FT B1026',), ('F9 FT  B1021.2',), ('F9 FT  B1031.2',)]

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %sql SELECT MISSION_OUTCOME, COUNT(*) as total_number FROM SPACEXTBL GROUP BY MISSION_OUTCOME;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Failure (in flight)', 1),
#  ('Success', 98),
#  ('Success ', 1),
#  ('Success (payload status unclear)', 1)]

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
# %sql select BOOSTER_VERSION as boosterversion from SPACEXTBL where PAYLOAD_MASS__KG_=(select max(PAYLOAD_MASS__KG_) from SPACEXTBL);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1060.2 ',),
#  ('F9 B5 B1058.3 ',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1060.3',),
#  ('F9 B5 B1049.7 ',)]

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 6,2) as month to get the months and substr(Date,0,5)='2015' for year.**

# %%
# %sql SELECT substr(Date, 6,2),MISSION_OUTCOME,BOOSTER_VERSION,LAUNCH_SITE FROM SPACEXTBL where substr(Date,0,5)='2015';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('01', 'Success', 'F9 v1.1 B1012', 'CCAFS LC-40'),
#  ('02', 'Success', 'F9 v1.1 B1013', 'CCAFS LC-40'),
#  ('03', 'Success', 'F9 v1.1 B1014', 'CCAFS LC-40'),
#  ('04', 'Success', 'F9 v1.1 B1015', 'CCAFS LC-40'),
#  ('04', 'Success', 'F9 v1.1 B1016', 'CCAFS LC-40'),
#  ('06', 'Failure (in flight)', 'F9 v1.1 B1018', 'CCAFS LC-40'),
#  ('12', 'Success', 'F9 FT B1019', 'CCAFS LC-40')]

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %%
# %sql select LANDING_OUTCOME, count(*) as count from SPACEXTBL where date = '2010-06-04' AND date <= '2017-03-20' GROUP by LANDING_OUTCOME ORDER BY count Desc
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Failure (parachute)', 1)]

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
